# %%
import pandas as pd
import basketball_reference_web_scraper as bb

# %%
from basketball_reference_web_scraper import client

# %%
yesterdays_player_box_scores = pd.DataFrame(client.player_box_scores(day=30, month=10, year=2024))

# %%
yesterdays_player_box_scores
# Out:
#           slug                name                       team       location  \
# 0    townska01  Karl-Anthony Towns       Team.NEW_YORK_KNICKS  Location.AWAY
# 1    schrode01     Dennis Schröder         Team.BROOKLYN_NETS  Location.AWAY
# 2    youngtr01          Trae Young         Team.ATLANTA_HAWKS  Location.AWAY
# 3    herroty01         Tyler Herro            Team.MIAMI_HEAT  Location.HOME
# 4    richani01       Nick Richards     Team.CHARLOTTE_HORNETS  Location.HOME
# ..         ...                 ...                        ...            ...
# 233  castlst01      Stephon Castle     Team.SAN_ANTONIO_SPURS  Location.AWAY
# 234  durenja01         Jalen Duren       Team.DETROIT_PISTONS  Location.AWAY
# 235  theisda01        Daniel Theis  Team.NEW_ORLEANS_PELICANS  Location.AWAY
# 236  terryda01         Dalen Terry         Team.CHICAGO_BULLS  Location.HOME
# 237  walkeja02       Jarace Walker        Team.INDIANA_PACERS  Location.HOME
#
# ...
